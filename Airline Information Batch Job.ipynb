# %% [markdown]
# ### read flight info from GMP&ICN web site
# - GMP site
#     * depaturey https://www.airport.co.kr/gimpo/extra/liveSchedule/liveScheduleList/layOut.do?langType=1&inoutType=OUT&cid=2015102611043202364&menuId=8
#     * arrival https://www.airport.co.kr/gimpo/extra/liveSchedule/liveScheduleList/layOut.do?langType=1&inoutType=IN&cid=2015102611052578964&menuId=10
#
# - ICN site
#     * depaturey https://www.airport.kr/ap/ko/dep/depPasSchList.do
#     * arrival https://www.airport.kr/ap/ko/arr/arrPasSchList.do
#
# - condition : date, airline code
# - goal : gate information
# - one day batch job

# %%
from lib.ReadAirlineInfomation import *

# %%
## read GMP airline information & save file
kac_sch_list(port='GMP')
# Out:
#    type   flt     from       to   tm gate
# 0     D   201  06 : 20  06 : 33  국내선    3
# 1     D   205  07 : 40  07 : 48  국내선    3
# 2     D   207  09 : 50  10 : 10  국내선   13
# 3     D  9887  11 : 00  11 : 00  국제선   34
# 4     D   209  11 : 15  11 : 15  국내선    1
# 5     D   257  12 : 50           국내선
# 6     D   213  12 : 55           국내선
# 7     D   215  13 : 50           국내선
# 8     D   217  14 : 45           국내선
# 9     D   219  15 : 50           국내선
# 10    D   221  16 : 55           국내선
# 11    D   223  18 : 20           국내선
# 12    D   225  19 : 25           국내선
# 13    D   227  19 : 45           국내선
# 14    D   229  20 : 00           국내선
# 15    D   231  20 : 20           국내선
# 16    A   202  09 : 15  09 : 11  국내선
# 17    A   258  09 : 50  10 : 28  국내선
# 18    A   204  10 : 30  10 : 34  국내선
# 19    A   208  11 : 10  11 : 12  국내선
# 20    A   210  13 : 15           국내선
# 21    A   212  14 : 10           국내선
# 22    A   216  16 : 10           국내선
# ...

# %%
## read GMP airline information & save file
icn_sch_list()
# Out:
#    type   flt   from     to  tm gate
# 0     D   621  07:47      -  T1  114
# 1     D   881  08:25      -  T1  128
# 2     D   601  08:58      -  T1  131
# 3     D   611  09:11      -  T1  124
# 4     D   931  09:48      -  T1  114
# 5     D   617  09:51      -  T1  102
# 6     D   641  10:18      -  T1  127
# 7     D   631  11:30      -  T1  102
# 8     D  9631  14:15      -  T1  130
# 9     D   613  14:35      -  T1  125
# 10    D   651  14:45      -  T1  128
# 11    D   615  15:25      -  T1  110
# 12    D  6231  15:35      -  T1  118
# 13    D   603  15:40      -  T1  112
# 14    D   643  15:50      -  T1  122
# 15    D   511  17:05      -  T1  131
# 16    D   591  18:00      -  T1  126
# 17    D   501  19:00      -  T1  127
# 18    D   503  20:35      -  T1  110
# 19    D   593  20:45      -  T1  118
# 20    D   541  20:50      -  T1  130
# 21    D   513  20:55      -  T1  122
# 22    D   595  21:45      -  T1  127
# 23    A   512      -  05:52  T1  114
# ...
